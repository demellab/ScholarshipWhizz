# %%
# %pip install --upgrade pip
# %pip install langchain-openai
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pip in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (21.2.4)
# Collecting pip
#   Using cached pip-25.3-py3-none-any.whl (1.8 MB)
# Installing collected packages: pip
# Successfully installed pip-25.3
# WARNING: You are using pip version 21.2.4; however, version 25.3 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: langchain-openai in /Users/abirademello/Library/Python/3.9/lib/python/site-packages (0.3.35)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.78 in /Users/abirademello/Library/Python/3.9/lib/python/site-packages (from langchain-openai) (0.3.79)
# Requirement already satisfied: openai<3.0.0,>=1.104.2 in /Users/abirademello/Library/Python/3.9/lib/python/site-packages (from langchain-openai) (2.6.1)
# Requirement already satisfied: tiktoken<1.0.0,>=0.7.0 in /Users/abirademello/Library/Python/3.9/lib/python/site-packages (from langchain-openai) (0.12.0)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in /Users/abirademello/Library/Python/3.9/lib/python/site-packages (from langchain-core<1.0.0,>=0.3.78->langchain-openai) (0.4.37)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /Users/abirademello/Library/Python/3.9/lib/python/site-packages (from langchain-core<1.0.0,>=0.3.78->langchain-openai) (9.1.2)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /Users/abirademello/Library/Python/3.9/lib/python/site-packages (from langchain-core<1.0.0,>=0.3.78->langchain-openai) (1.33)
# Requirement already satisfied: PyYAML<7.0.0,>=5.3.0 in /Users/abirademello/Library/Python/3.9/lib/python/site-packages (from langchain-core<1.0.0,>=0.3.78->langchain-openai) (6.0.3)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in /Users/abirademello/Library/Python/3.9/lib/python/site-packages (from langchain-core<1.0.0,>=0.3.78->langchain-openai) (4.15.0)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in /Users/abirademello/Library/Python/3.9/lib/python/site-packages (from langchain-core<1.0.0,>=0.3.78->langchain-openai) (25.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /Users/abirademello/Library/Python/3.9/lib/python/site-packages (from langchain-core<1.0.0,>=0.3.78->langchain-openai) (2.12.3)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/abirademello/Library/Python/3.9/lib/python/site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<1.0.0,>=0.3.78->langchain-openai) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/abirademello/Library/Python/3.9/lib/python/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<1.0.0,>=0.3.78->langchain-openai) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in /Users/abirademello/Library/Python/3.9/lib/python/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<1.0.0,>=0.3.78->langchain-openai) (3.11.4)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /Users/abirademello/Library/Python/3.9/lib/python/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<1.0.0,>=0.3.78->langchain-openai) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in /Users/abirademello/Library/Python/3.9/lib/python/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<1.0.0,>=0.3.78->langchain-openai) (2.32.5)
# Requirement already satisfied: zstandard>=0.23.0 in /Users/abirademello/Library/Python/3.9/lib/python/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<1.0.0,>=0.3.78->langchain-openai) (0.25.0)
# Requirement already satisfied: anyio in /Users/abirademello/Library/Python/3.9/lib/python/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<1.0.0,>=0.3.78->langchain-openai) (4.11.0)
# Requirement already satisfied: certifi in /Users/abirademello/Library/Python/3.9/lib/python/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<1.0.0,>=0.3.78->langchain-openai) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in /Users/abirademello/Library/Python/3.9/lib/python/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<1.0.0,>=0.3.78->langchain-openai) (1.0.9)
# Requirement already satisfied: idna in /Users/abirademello/Library/Python/3.9/lib/python/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<1.0.0,>=0.3.78->langchain-openai) (3.11)
# Requirement already satisfied: h11>=0.16 in /Users/abirademello/Library/Python/3.9/lib/python/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<1.0.0,>=0.3.78->langchain-openai) (0.16.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/abirademello/Library/Python/3.9/lib/python/site-packages (from openai<3.0.0,>=1.104.2->langchain-openai) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in /Users/abirademello/Library/Python/3.9/lib/python/site-packages (from openai<3.0.0,>=1.104.2->langchain-openai) (0.11.1)
# Requirement already satisfied: sniffio in /Users/abirademello/Library/Python/3.9/lib/python/site-packages (from openai<3.0.0,>=1.104.2->langchain-openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /Users/abirademello/Library/Python/3.9/lib/python/site-packages (from openai<3.0.0,>=1.104.2->langchain-openai) (4.67.1)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /Users/abirademello/Library/Python/3.9/lib/python/site-packages (from anyio->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<1.0.0,>=0.3.78->langchain-openai) (1.3.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/abirademello/Library/Python/3.9/lib/python/site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<1.0.0,>=0.3.78->langchain-openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /Users/abirademello/Library/Python/3.9/lib/python/site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<1.0.0,>=0.3.78->langchain-openai) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/abirademello/Library/Python/3.9/lib/python/site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<1.0.0,>=0.3.78->langchain-openai) (0.4.2)
# Requirement already satisfied: regex>=2022.1.18 in /Users/abirademello/Library/Python/3.9/lib/python/site-packages (from tiktoken<1.0.0,>=0.7.0->langchain-openai) (2025.10.23)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/abirademello/Library/Python/3.9/lib/python/site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<1.0.0,>=0.3.78->langchain-openai) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/abirademello/Library/Python/3.9/lib/python/site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<1.0.0,>=0.3.78->langchain-openai) (2.5.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install langchain-community
# !pip install langchain-openai langgraph langchain-core
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: langchain-community in /Users/abirademello/Library/Python/3.9/lib/python/site-packages (0.3.31)
# Requirement already satisfied: langchain-core<2.0.0,>=0.3.78 in /Users/abirademello/Library/Python/3.9/lib/python/site-packages (from langchain-community) (0.3.79)
# Requirement already satisfied: langchain<2.0.0,>=0.3.27 in /Users/abirademello/Library/Python/3.9/lib/python/site-packages (from langchain-community) (0.3.27)
# Requirement already satisfied: SQLAlchemy<3.0.0,>=1.4.0 in /Users/abirademello/Library/Python/3.9/lib/python/site-packages (from langchain-community) (2.0.44)
# Requirement already satisfied: requests<3.0.0,>=2.32.5 in /Users/abirademello/Library/Python/3.9/lib/python/site-packages (from langchain-community) (2.32.5)
# Requirement already satisfied: PyYAML<7.0.0,>=5.3.0 in /Users/abirademello/Library/Python/3.9/lib/python/site-packages (from langchain-community) (6.0.3)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /Users/abirademello/Library/Python/3.9/lib/python/site-packages (from langchain-community) (3.13.2)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /Users/abirademello/Library/Python/3.9/lib/python/site-packages (from langchain-community) (9.1.2)
# Requirement already satisfied: dataclasses-json<0.7.0,>=0.6.7 in /Users/abirademello/Library/Python/3.9/lib/python/site-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in /Users/abirademello/Library/Python/3.9/lib/python/site-packages (from langchain-community) (2.11.0)
# Requirement already satisfied: langsmith<1.0.0,>=0.1.125 in /Users/abirademello/Library/Python/3.9/lib/python/site-packages (from langchain-community) (0.4.37)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in /Users/abirademello/Library/Python/3.9/lib/python/site-packages (from langchain-community) (0.4.3)
# Requirement already satisfied: numpy>=1.26.2 in /Users/abirademello/Library/Python/3.9/lib/python/site-packages (from langchain-community) (2.0.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /Users/abirademello/Library/Python/3.9/lib/python/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /Users/abirademello/Library/Python/3.9/lib/python/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /Users/abirademello/Library/Python/3.9/lib/python/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (4.0.3)
# Requirement already satisfied: attrs>=17.3.0 in /Users/abirademello/Library/Python/3.9/lib/python/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/abirademello/Library/Python/3.9/lib/python/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/abirademello/Library/Python/3.9/lib/python/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /Users/abirademello/Library/Python/3.9/lib/python/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Users/abirademello/Library/Python/3.9/lib/python/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.22.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /Users/abirademello/Library/Python/3.9/lib/python/site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /Users/abirademello/Library/Python/3.9/lib/python/site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (0.9.0)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.9 in /Users/abirademello/Library/Python/3.9/lib/python/site-packages (from langchain<2.0.0,>=0.3.27->langchain-community) (0.3.11)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /Users/abirademello/Library/Python/3.9/lib/python/site-packages (from langchain<2.0.0,>=0.3.27->langchain-community) (2.12.3)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /Users/abirademello/Library/Python/3.9/lib/python/site-packages (from langchain-core<2.0.0,>=0.3.78->langchain-community) (1.33)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in /Users/abirademello/Library/Python/3.9/lib/python/site-packages (from langchain-core<2.0.0,>=0.3.78->langchain-community) (4.15.0)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in /Users/abirademello/Library/Python/3.9/lib/python/site-packages (from langchain-core<2.0.0,>=0.3.78->langchain-community) (25.0)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/abirademello/Library/Python/3.9/lib/python/site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=0.3.78->langchain-community) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/abirademello/Library/Python/3.9/lib/python/site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in /Users/abirademello/Library/Python/3.9/lib/python/site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (3.11.4)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /Users/abirademello/Library/Python/3.9/lib/python/site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in /Users/abirademello/Library/Python/3.9/lib/python/site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (0.25.0)
# Requirement already satisfied: anyio in /Users/abirademello/Library/Python/3.9/lib/python/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (4.11.0)
# Requirement already satisfied: certifi in /Users/abirademello/Library/Python/3.9/lib/python/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in /Users/abirademello/Library/Python/3.9/lib/python/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (1.0.9)
# Requirement already satisfied: idna in /Users/abirademello/Library/Python/3.9/lib/python/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (3.11)
# Requirement already satisfied: h11>=0.16 in /Users/abirademello/Library/Python/3.9/lib/python/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/abirademello/Library/Python/3.9/lib/python/site-packages (from pydantic<3.0.0,>=2.7.4->langchain<2.0.0,>=0.3.27->langchain-community) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /Users/abirademello/Library/Python/3.9/lib/python/site-packages (from pydantic<3.0.0,>=2.7.4->langchain<2.0.0,>=0.3.27->langchain-community) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/abirademello/Library/Python/3.9/lib/python/site-packages (from pydantic<3.0.0,>=2.7.4->langchain<2.0.0,>=0.3.27->langchain-community) (0.4.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in /Users/abirademello/Library/Python/3.9/lib/python/site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community) (1.2.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/abirademello/Library/Python/3.9/lib/python/site-packages (from requests<3.0.0,>=2.32.5->langchain-community) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/abirademello/Library/Python/3.9/lib/python/site-packages (from requests<3.0.0,>=2.32.5->langchain-community) (2.5.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /Users/abirademello/Library/Python/3.9/lib/python/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.7->langchain-community) (1.1.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /Users/abirademello/Library/Python/3.9/lib/python/site-packages (from anyio->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (1.3.0)
# Requirement already satisfied: sniffio>=1.1 in /Users/abirademello/Library/Python/3.9/lib/python/site-packages (from anyio->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (1.3.1)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: langchain-openai in /Users/abirademello/Library/Python/3.9/lib/python/site-packages (0.3.35)
# Requirement already satisfied: langgraph in /Users/abirademello/Library/Python/3.9/lib/python/site-packages (0.6.11)
# Requirement already satisfied: langchain-core in /Users/abirademello/Library/Python/3.9/lib/python/site-packages (0.3.79)
# Requirement already satisfied: openai<3.0.0,>=1.104.2 in /Users/abirademello/Library/Python/3.9/lib/python/site-packages (from langchain-openai) (2.6.1)
# Requirement already satisfied: tiktoken<1.0.0,>=0.7.0 in /Users/abirademello/Library/Python/3.9/lib/python/site-packages (from langchain-openai) (0.12.0)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in /Users/abirademello/Library/Python/3.9/lib/python/site-packages (from langchain-core) (0.4.37)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /Users/abirademello/Library/Python/3.9/lib/python/site-packages (from langchain-core) (9.1.2)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /Users/abirademello/Library/Python/3.9/lib/python/site-packages (from langchain-core) (1.33)
# Requirement already satisfied: PyYAML<7.0.0,>=5.3.0 in /Users/abirademello/Library/Python/3.9/lib/python/site-packages (from langchain-core) (6.0.3)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in /Users/abirademello/Library/Python/3.9/lib/python/site-packages (from langchain-core) (4.15.0)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in /Users/abirademello/Library/Python/3.9/lib/python/site-packages (from langchain-core) (25.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /Users/abirademello/Library/Python/3.9/lib/python/site-packages (from langchain-core) (2.12.3)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/abirademello/Library/Python/3.9/lib/python/site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/abirademello/Library/Python/3.9/lib/python/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in /Users/abirademello/Library/Python/3.9/lib/python/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (3.11.4)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /Users/abirademello/Library/Python/3.9/lib/python/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in /Users/abirademello/Library/Python/3.9/lib/python/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (2.32.5)
# Requirement already satisfied: zstandard>=0.23.0 in /Users/abirademello/Library/Python/3.9/lib/python/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (0.25.0)
# Requirement already satisfied: anyio in /Users/abirademello/Library/Python/3.9/lib/python/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core) (4.11.0)
# Requirement already satisfied: certifi in /Users/abirademello/Library/Python/3.9/lib/python/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in /Users/abirademello/Library/Python/3.9/lib/python/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core) (1.0.9)
# Requirement already satisfied: idna in /Users/abirademello/Library/Python/3.9/lib/python/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core) (3.11)
# Requirement already satisfied: h11>=0.16 in /Users/abirademello/Library/Python/3.9/lib/python/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core) (0.16.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/abirademello/Library/Python/3.9/lib/python/site-packages (from openai<3.0.0,>=1.104.2->langchain-openai) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in /Users/abirademello/Library/Python/3.9/lib/python/site-packages (from openai<3.0.0,>=1.104.2->langchain-openai) (0.11.1)
# Requirement already satisfied: sniffio in /Users/abirademello/Library/Python/3.9/lib/python/site-packages (from openai<3.0.0,>=1.104.2->langchain-openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /Users/abirademello/Library/Python/3.9/lib/python/site-packages (from openai<3.0.0,>=1.104.2->langchain-openai) (4.67.1)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /Users/abirademello/Library/Python/3.9/lib/python/site-packages (from anyio->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core) (1.3.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/abirademello/Library/Python/3.9/lib/python/site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /Users/abirademello/Library/Python/3.9/lib/python/site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/abirademello/Library/Python/3.9/lib/python/site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core) (0.4.2)
# Requirement already satisfied: regex>=2022.1.18 in /Users/abirademello/Library/Python/3.9/lib/python/site-packages (from tiktoken<1.0.0,>=0.7.0->langchain-openai) (2025.10.23)
# Requirement already satisfied: langgraph-checkpoint<4.0.0,>=2.1.0 in /Users/abirademello/Library/Python/3.9/lib/python/site-packages (from langgraph) (2.1.2)
# Requirement already satisfied: langgraph-prebuilt<0.7.0,>=0.6.0 in /Users/abirademello/Library/Python/3.9/lib/python/site-packages (from langgraph) (0.6.5)
# Requirement already satisfied: langgraph-sdk<0.3.0,>=0.2.2 in /Users/abirademello/Library/Python/3.9/lib/python/site-packages (from langgraph) (0.2.9)
# Requirement already satisfied: xxhash>=3.5.0 in /Users/abirademello/Library/Python/3.9/lib/python/site-packages (from langgraph) (3.6.0)
# Requirement already satisfied: ormsgpack>=1.10.0 in /Users/abirademello/Library/Python/3.9/lib/python/site-packages (from langgraph-checkpoint<4.0.0,>=2.1.0->langgraph) (1.11.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/abirademello/Library/Python/3.9/lib/python/site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/abirademello/Library/Python/3.9/lib/python/site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core) (2.5.0)

# %%
from typing import Literal
from langchain_core.messages import HumanMessage
from langchain_openai.chat_models import ChatOpenAI
from langchain_openai.embeddings import OpenAIEmbeddings
from langchain_community.document_loaders import UnstructuredURLLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain_community.vectorstores import Chroma
from langchain_core.tools import tool
from langgraph.checkpoint.memory import MemorySaver
from langgraph.graph import END, START, StateGraph, MessagesState
from langgraph.prebuilt import ToolNode
import os

# %%
import pandas as pd
from langchain.schema import Document
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain_community.vectorstores import Chroma

# %%
# Set environment variables for compatibility
import os
from langchain_openai.chat_models import ChatOpenAI

# Define base URL and model parameters
os.environ["OPENAI_API_KEY"] = "EMPTY"  # placeholder key
os.environ["OPENAI_BASE_URL"] = "http://research-ai.tail69783d.ts.net:8001/v1"

# Initialize the model using LangChain's OpenAI-compatible interface
chat = ChatOpenAI(
    base_url=os.environ["OPENAI_BASE_URL"],
    api_key=os.environ["OPENAI_API_KEY"],
    model="openai/gpt-oss-20b",
    temperature=0,
    max_completion_tokens=10000
)

# %%
# from langchain_community.embeddings import HuggingFaceEmbeddings
# embeddings = HuggingFaceEmbeddings(model_name="sentence-transformers/all-MiniLM-L6-v2")

# %%
@tool
def retrieve_context(query: str):
    """Search for relevant documents."""
    urls = [
        "https://yconic.com/?mc_cid=583c4c0067&mc_eid=0cff01aa61",
        "https://www.educanada.ca/scholarships-bourses/non_can/index.aspx?lang=eng"
    ]

    loader = UnstructuredURLLoader(urls=urls)
    docs = loader.load()

    text_splitter = RecursiveCharacterTextSplitter(chunk_size=2000, chunk_overlap=50)
    doc_splits = text_splitter.split_documents(docs)

    #text into embeddings - to compress the size of the text chunk, and readable by the agent 
    # saving the vector into the chroma db
    
    vectorstore = Chroma.from_documents(
        documents=doc_splits,
        collection_name="python_docs",
        embedding=OpenAIEmbeddings()
    )

    retriever = vectorstore.as_retriever()
    results = retriever.invoke(query)
    return "\n".join([doc.page_content for doc in results])

# %% [markdown]
# agent and tools
#
# define LLM and list of available tool functions

# %%
# Bind our retrieval tool and connect it to the model

# List of tools (functions) to use
tools = [retrieve_context]

# Create a ToolNode for LangGraph - run this tool when the agent wants and decides if the tool needs to be run
tool_node = ToolNode(tools)

# Instantiate a Chat model using your internal vLLM backend (OpenAI-compatible)
from langchain_openai import ChatOpenAI

model = ChatOpenAI(
    base_url="http://research-ai.tail69783d.ts.net:8001/v1",  # your internal endpoint
    api_key="EMPTY",  # not needed for local/vLLM servers
    model="openai/gpt-oss-20b",  # adjust if your local model name differs
    temperature=0
).bind_tools(tools)

print("Internal vLLM model connected and tools bound successfully")
# Out:
# Internal vLLM model connected and tools bound successfully

# %%
# Function to decide whether to continue or stop the workflow

def should_continue(state: MessagesState) -> Literal["tools", END]:
    """Determine whether to continue the graph or end the conversation."""
    messages = state["messages"]
    last_message = messages[-1]

    # If the LLM makes a tool call, go to the "tools" node
    if last_message.tool_calls:
        return "tools"

    # Otherwise, finish the workflow
    return END

# %%
# Function that invokes the model
def call_model(state: MessagesState):
    messages = state["messages"]
    response = model.invoke(messages)
    return {"messages": [response]}  # Returns as a list to add to the state

# %%
# Define the workflow with LangGraph
workflow = StateGraph(MessagesState)

# Add nodes to the graph
workflow.add_node("agent", call_model)
workflow.add_node("tools", tool_node)

# Connect nodes
workflow.add_edge(START, "agent")
workflow.add_conditional_edges("agent", should_continue)  # Decision after the "agent" node
workflow.add_edge("tools", "agent")  # Cycle between tools and agent

# %%
checkpointer = MemorySaver()
app = workflow.compile()

# %%
final_state = app.invoke(
    {
        "messages": [HumanMessage(content="print 5 scholarships in 2025")],
        "configurable": {"thread_id": 42}
    }
)

print(final_state["messages"][-1].content)
# Out:
# I’m sorry, but I’m currently unable to fetch up‑to‑date external data because the tool I use for retrieving context requires a package that isn’t available in this environment. However, I can still give you a list of five well‑known scholarships that are typically offered for the 2025 academic year (or that you can apply for in 2025). These are based on the most recent information I have up to 2024, and most of them are renewed annually:
#
# | # | Scholarship | Eligibility | Typical Deadline (2025) | Notes |
# |---|-------------|-------------|------------------------|-------|
# | 1 | **Fulbright U.S. Student Program** | U.S. citizens, 18+ years, bachelor’s degree (or in progress) | Usually mid‑January for the 2025–26 academic year | International research, teaching, or study abroad. Requires a strong academic record and a clear project proposal. |
# | 2 | **Rhodes Scholarship (University of Oxford)** | Citizens of the U.S., U.K., Canada, Australia, New Zealand, South Africa, or other eligible countries; 18–24 years; bachelor’s degree (or in progress) | Early March (application opens) | Highly competitive; focuses on leadership, academic excellence, and commitment to service. |
# | 3 | **Gates Millennium Scholars Program** | U.S. citizens or permanent residents; 18–25 years; high school seniors or college students; low‑income background | Early March (application opens) | Provides full tuition, fees, books, and a stipend. Requires a strong academic record and community service. |
# | 4 | **National Science Foundation (NSF) Graduate Research Fellowship** | U.S. citizens, nationals, or permanent residents; 18+ years; pursuing a master’s or Ph.D. in STEM | Early March (application opens) | Covers stipend, tuition, and a cost‑of‑living allowance for 3 years. Requires a research proposal and strong academic record. |
# | 5 | **The Coca‑Cola Scholars Program** | U.S. citizens or permanent residents; 18–25 years; high school seniors or college students; low‑income background | Early March (application opens) | Provides a full scholarship to a U.S. college or university, plus a $5,000 stipend and a summer internship. |
#
# ### How to Find the Exact 2025 Dates
# - **Official Websites**: Each scholarship’s official site will list the 2025 application window. For example, the Fulbright U.S. Student Program’s site (https://us.fulbrightonline.org/) and the Rhodes Trust’s site (https://www.rhodeshouse.ox.ac.uk/) are reliable sources.
# - **University Financial Aid Offices**: Many universities maintain a calendar of external scholarship deadlines and can confirm whether a scholarship is still active for 2025.
# - **Scholarship Databases**: Sites like Fastweb, Chegg, or the College Board’s Scholarship Search allow you to filter by year and eligibility.
#
# If you need more specific details (e.g., exact application dates, required documents, or how to prepare a strong application), let me know and I can walk you through the typical process for each scholarship.
